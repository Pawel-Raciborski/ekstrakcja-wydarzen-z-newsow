# %%
import requests
from bs4 import BeautifulSoup

urls = {
    "BIZNES" : {
        "url" : "https://businessinsider.com.pl/biznes",
        "pages" : 30,
        "query_type": "query"
        },
    "WYPADEK" : {
        "url" : "https://policja.pl/pol/aktualnosci?archiwum=1&ida[6]=2140",
        "pages" : 30,
        "query_type": "query"
    },
    "POLITYKA": {
        "url" : "https://www.rp.pl/wydarzenia/kraj/polityka",
        "pages" : 40,
        "query_type" : "path"
    }
}


def get_page_data(url):
    try:
        response = requests.get(url)
        
        if response.status_code == 200:
            return response.text
            print("Pobrano zawartość strony pomyślnie.")
        else:
            print(f"Błąd podczas pobierania strony. Kod statusu: {response.status_code}")
            exit()

    except requests.exceptions.RequestException as e:
        print(f"Wystąpił błąd połączenia: {e}")
        exit()

def get_business_main_data(url,page):
    if page > 1:
        url = url + f'?page={page}'
        
    content = get_page_data(url)
    soup = BeautifulSoup(content, 'html.parser')
    main = soup.find('main', class_='main')
    return main
    
def get_parsed_page_data(url,page,query_type):
    if page > 1:
        if query_type == 'query':
            separator = '&' if '?' in url else '?'
            url = f"{url}{separator}page={page}"
        elif query_type == 'path':
            url = f"{url.rstrip('/')}/{page}"
    
    content = get_page_data(url)
    soup = BeautifulSoup(content, 'html.parser')
    return soup

def get_container(content, elem_to_extract, class_name):
    return content.find(elem_to_extract,class_= class_name)
    
def extract_headers(element, header, class_name=''):
    return element.find_all(header,class_= class_name)

def extract_text(elements):
    text = []
    for element in elements:
        text.append(element.get_text(strip=True))
    return text

def get_business_headers(url_data):
    text_headers = []
    for page in range(20,url_data['pages']+1):
        content = get_parsed_page_data(url_data['url'],page,url_data['query_type'])
        main_container = get_container(content,'main','main')
        headers = extract_headers(main_container,'h2','item_title')
        text_headers.extend(extract_text(headers))
    return text_headers

def get_accidents_headers(url_data):
    text_headers = []
    for page in range(20,url_data['pages']+1):
        content = get_parsed_page_data(url_data['url'],page,url_data['query_type'])
        main_container = get_container(content,'div','okno')
        headers = extract_headers(main_container,'h3')
        text_headers.extend(extract_text(headers))
    return text_headers

def get_politics_headers(url_data):
    text_headers = []
    for page in range(20,url_data['pages']+1):
        content = get_parsed_page_data(url_data['url'],page,url_data['query_type'])
        headers = extract_headers(content,'h2','t--60')
        text_headers.extend(extract_text(headers))
    return text_headers

categories_headers = {
    "BIZNES" : [],
    "WYPADEK": [],
    "POLITYKA": []
}

categories_headers['BIZNES'] = get_business_headers(urls['BIZNES'])
categories_headers['WYPADEK'] = get_accidents_headers(urls['WYPADEK'])
categories_headers['POLITYKA'] = get_politics_headers(urls['POLITYKA'])

# %%
import pandas as pd
s = pd.Series(categories_headers)
df = s.explode().reset_index()
df.columns = ['Wydarzenie', 'Naglowek']
df.to_csv('wydarzenia_new.csv', index=False, encoding='utf-8')
print(df)
# Out:
#      Wydarzenie                                           Naglowek
# 0        BIZNES  Przyszłość już nie czeka. Dlaczego cyfrowa tra...
# 1        BIZNES  Jest wyrok w sprawie największego oszustwa w h...
# 2        BIZNES  Koniec polityki? Elon Musk zapowiada powrót do...
# 3        BIZNES  Kinga Piecuch: Właściwie nie wiedziałam, co to...
# 4        BIZNES  Najbogatsza szwedzka rodzina zbuduje "fabrykę ...
# ...         ...                                                ...
# 1098   POLITYKA  Eastern Sentry i wojska NATO w Polsce. Prezyde...
# 1099   POLITYKA  Sondaż: Czy Polacy chcą odejścia Szymona Hołow...
# 1100   POLITYKA  Rosyjskie drony nad Polską. Andrzej Duda: Rosj...
# 1101   POLITYKA  Sondaż: Władysław Kosiniak-Kamysz czy Mariusz ...
# 1102   POLITYKA  Donald Tusk: Mark Rutte ogłosił bezpośrednią o...
#
# [1103 rows x 2 columns]

# %%
urls = {"WYPADEK" : {
        "url" : "https://policja.pl/pol/aktualnosci?archiwum=1&ida[6]=2140",
        "pages" : 10,
        "query_type": "query"
    }
}

categories_headers['WYPADEK'] = get_accidents_headers(urls['WYPADEK'])

# %%
print(categories_headers['WYPADEK'])
print(len(categories_headers['WYPADEK']))
# Out:
# ['Policjantka z Komisariatu II w Radomiu będąc po służbie, zatrzymała nietrzeźwego kierowcę', 'Bądź gotowy do bezpiecznej, świątecznej drogi!', 'O krok od tragedii. 67-latka niemal potrąciła pieszych na pasach', 'Policyjny pościg za 35-latkiem bez prawa jazdy i z narkotykami', 'Wjechał hulajnogą na przejście i uderzył w osobówkę. 8-latek trafił do szpitala', 'Autobus i rowerzystka - poważne zdarzenie w Międzyzdrojach', 'Potrącenie 9-letniej dziewczynki na ulicy Pamiątki', 'Wjechała na przejazd kolejowy, kiedy zamykały się rogatki', 'Do 20 lat więzienia grozi kierowcy, który śmiertelnie potrącił 78-letnią rowerzystkę, a potem uciekł', 'Pod prąd na rondzie, wprost na nadjeżdżający radiowóz', 'Wjechał hulajnogą elektryczną wprost pod nadjeżdżające auto', '13-latek uciekał audi przed ostrowieckimi policjantami', 'Szponcił na drodze - zatrzymali go policjanci', 'Uciekał przed policjantami, bo nie posiadał uprawnień do kierowania. 28-latek zatrzymany po pościgu', 'Policjanci z Kluczborka uratowali życie 87-latkowi', 'Na drodze nie ma miejsca na alkohol – działania „Trzeźwy wieczór” na lubuskich drogach', 'Tymczasowy areszt dla 47-letniego sprawcy tragicznego wypadku drogowego', 'Sprawdź światła pojazdu. Bezpłatnie!', '52-latek zatrzymany po policyjnym pościgu. Kierował bez uprawnień i pod wpływem narkotyków', 'Śmiertelne potrącenie motorowerzysty w powiecie parczewskim', 'Potrącił pieszego i uciekł - zarzuty dla 80-letniego kierowcy', 'Niebezpieczne zdarzenie przed przejazdem drogowo-kolejowym', 'Bezpieczne Andrzejki 2025', 'Nie ustąpił pierwszeństwa i doprowadził do kolizji', 'Policyjne działania "Prędkość"', 'Policyjny pościg ulicami Wrocławia. Uciekinierzy doprowadzili do poważnego wypadku', 'Nietrzeźwy kierujący bez uprawnień uderzył w latarnię - sprawa trafi do sądu', 'Policyjny pościg zakończony zatrzymaniem', 'Nocny pościg w Zielonej Górze. Policjanci zatrzymali kierowcę z trzema zakazami i dwoma listami gończymi', 'Policjanci ewakuowali osoby uwięzione przez zamieć śnieżną w swoich samochodach', 'Pięciokrotne złamanie sądowego zakazu zakończone wyrokiem', 'Zawodowi kierowcy nadal lekceważą przepisy na A2. 20 wykroczeń w zaledwie 3 godziny', '„Twoje światła – Nasze bezpieczeństwo”  kampania na rzecz sprawnych świateł', 'Wjechał na skrzyżowanie na czerwonym świetle i doprowadził do kolizji', 'Policyjny pościg i skuteczne zatrzymanie 26-latka w sportowym audi', 'Nie zatrzymał się do kontroli, bo był poszukiwany, pod wpływem narkotyków i miał cofnięte uprawnienia', 'Bądź widoczny – noś odblaski. Jesień to czas, gdy pieszy musi świecić przykładem', 'Na hulajnodze wjechał w kobietę z wózkiem. Policjanci skierują sprawę do sądu', 'Policyjny pościg za 16-latkiem bez uprawnień i pod wpływem amfetaminy', '19-latek usłyszał wyrok w trybie przyspieszonym. Bezwzględne więzienie', 'Niebezpieczne zachowania kierowców na przejściu w bydgoskim Fordonie', 'Wołowscy policjanci zatrzymali 37-letniego mężczyznę za niezatrzymanie się do kontroli, łamania zakazu sądowego, posiadanie narkotyków i kilka innych naruszeń prawa', 'Jeleniogórscy policjanci po pościgu zatrzymali 30-latka podejrzewanego m.in. o kradzież pojazdu i czynną napaść na funkcjonariusza', 'Pijany doprowadził do dachowania auta i uciekł z miejsca zdarzenia, nie udzielając pomocy poszkodowanemu pasażerowi', 'Promile i brak karty rowerowej. Sprawą 14-latka zajmie się sąd rodzinny', '12-latka na hulajnodze potrącona na pasach', 'Pijany kierowca potrącił policjantkę', 'Pościg za 16-latkiem na hulajnodze elektrycznej', 'Na drodze nie ma miejsca na błędy! Potrącenie pieszej w oku kamery', 'Był nietrzeźwy i uciekał - zatrzymali go policjanci', 'Para włamywaczy zatrzymana i odzyskana cześć skradzionego mienia - sukces wałbrzyskich kryminalnych', 'Przyjechał pod komendę…na podwójnym gazie', 'Dwukrotnie jechał z prędkością 111 km/h', 'O włos od tragedii - STOP AGRESJI DROGOWEJ', 'Nietypowe zdarzenie drogowe w Koszalinie - 81-letnia kierująca hulajnogą elektryczną nie wyhamowała i uderzyła w ...
# 300
